# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Importing the Dataset
df = pd.read_excel("Cereals1.xlsx")
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 1                    All-Bran   K    C        70        4    1     260    9.0
# 2   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 3              Almond_Delight   R    C       110        2    2     200    1.0
# 4     Apple_Cinnamon_Cheerios   G    C       110        2    2     180    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 71                    Triples   G    C       110        2    1     250    0.0
# 72                       Trix   G    C       110        1    1     140    0.0
# 73                 Wheat_Chex   R    C       100        3    1     230    3.0
# 74                   Wheaties   G    C       100        3    1     200    3.0
# 75        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     8.0       8     135         0      3     1.0  1.00  33.983679
# 1     7.0       5     320        25      3     1.0  0.33  59.425505
# 2     8.0       0     330        25      3     1.0  0.50  93.704912
# 3    14.0       8      -1        25      3     1.0  0.75  34.384843
# 4    10.5      10      70        25      1     1.0  0.75  29.509541
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 71   21.0       3      60        25      3     1.0  0.75  39.106174
# 72   13.0      12      25        25      2     1.0  1.00  27.753301
# 73   17.0       3     115        25      1     1.0  0.67  49.787445
# 74   17.0       3     110        25      1     1.0  1.00  51.592193
# 75   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [76 rows x 16 columns]

# %%
# To check if there are any null values
df.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
df1 = df[["calories","protein","fat","sodium","fiber","carbo","sugars","potass","vitamins","shelf","weight","cups","rating"]]
#df1 = df[["name","mfr","type"]].dropna()
df1
#(df1<0).values.any()
# Out:
#     calories  protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  \
# 0        120        3    5      15    2.0    8.0       8     135         0
# 1         70        4    1     260    9.0    7.0       5     320        25
# 2         50        4    0     140   14.0    8.0       0     330        25
# 3        110        2    2     200    1.0   14.0       8      -1        25
# 4        110        2    2     180    1.5   10.5      10      70        25
# ..       ...      ...  ...     ...    ...    ...     ...     ...       ...
# 71       110        2    1     250    0.0   21.0       3      60        25
# 72       110        1    1     140    0.0   13.0      12      25        25
# 73       100        3    1     230    3.0   17.0       3     115        25
# 74       100        3    1     200    3.0   17.0       3     110        25
# 75       110        2    1     200    1.0   16.0       8      60        25
#
#     shelf  weight  cups     rating
# 0       3     1.0  1.00  33.983679
# 1       3     1.0  0.33  59.425505
# 2       3     1.0  0.50  93.704912
# 3       3     1.0  0.75  34.384843
# 4       1     1.0  0.75  29.509541
# ..    ...     ...   ...        ...
# 71      3     1.0  0.75  39.106174
# 72      2     1.0  1.00  27.753301
# 73      1     1.0  0.67  49.787445
# 74      1     1.0  1.00  51.592193
# 75      1     1.0  0.75  36.187559
#
# [76 rows x 13 columns]

# %% [markdown]
# ### 1) Create a table with the 5-number summary of all the numeric attributes.

# %%
df1.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.368421   2.526316   1.013158  160.065789   2.048684  14.723684
# std     19.139378   1.089020   1.013159   84.318813   2.219038   4.160444
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  132.500000   0.750000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  14.500000
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   76.000000   76.000000  76.000000  76.000000  76.000000
# mean    6.934211   93.657895   28.289474   2.197368   1.030000   0.827500
# std     4.473136   68.502565   22.487813   0.832982   0.151438   0.227204
# min    -1.000000   -1.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   40.000000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000  120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  76.000000
# mean   42.327057
# std    13.820602
# min    18.042851
# 25%    32.932466
# 50%    40.253086
# 75%    50.780847
# max    93.704912

# %% [markdown]
# ### 2) For each of the numeric attributes (proteins upto vitamins) , identify and replace all missing data(indicated with -1) with the arithmetic mean of the attribute.

# %%
df[["protein","fat","sodium","fiber","carbo","sugars","potass","vitamins"]][df.values == -1]
# Out:
#     protein  fat  sodium  fiber  carbo  sugars  potass  vitamins
# 3         2    2     200    1.0   14.0       8      -1        25
# 19        3    0      80    1.0   21.0       0      -1         0
# 56        5    2       0    2.7   -1.0      -1     110         0
# 56        5    2       0    2.7   -1.0      -1     110         0

# %%
df["carbo"].replace({-1 : df["carbo"].mean()},inplace = True)

df[df.values == -1]
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 3           Almond_Delight   R    C       110        2    2     200    1.0
# 19  Cream_of_Wheat_(Quick)   N    H       100        3    0      80    1.0
# 56          Quaker_Oatmeal   Q    H       100        5    2       0    2.7
#
#         carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 3   14.000000       8      -1        25      3     1.0  0.75  34.384843
# 19  21.000000       0      -1         0      2     1.0  1.00  64.533816
# 56  14.723684      -1     110         0      1     1.0  0.67  50.828392

# %%
df["sugars"].replace({-1 : df["sugars"].mean()},inplace = True)
df["potass"].replace({-1 : df2["potass"].mean()},inplace = True)
df[df.values == -1]
# Out:
# Empty DataFrame
# Columns: [name, mfr, type, calories, protein, fat, sodium, fiber, carbo, sugars, potass, vitamins, shelf, weight, cups, rating]
# Index: []

# %% [markdown]
# #### Hence, there are no more missing values that are replaced with -1 and the changes have been directly applied to the intial dataframe df.

# %%
# Now there are no missing values(that are replaced with -1) in the dataframe df
# To check again,
df[df.values == -1]
# Out:
# Empty DataFrame
# Columns: [name, mfr, type, calories, protein, fat, sodium, fiber, carbo, sugars, potass, vitamins, shelf, weight, cups, rating]
# Index: []

# %% [markdown]
# Inserting 'inplace = True' in the replace function is mandatory to make the changes in the original dataset.

# %% [markdown]
# ### 3) Create a table with the 5-number summary of all the numeric attributes after treating  missing values. Do you think the strategy used in dealing with missing values was  effective?

# %%
df2 = df[["protein","fat","sodium","fiber","carbo","sugars","potass","vitamins"]]
sum = df2.describe()
sum
# Out:
#          protein        fat      sodium      fiber      carbo     sugars  \
# count  76.000000  76.000000   76.000000  76.000000  76.000000  76.000000
# mean    2.526316   1.013158  160.065789   2.048684  14.930575   7.038608
# std     1.089020   1.013159   84.318813   2.219038   3.737575   4.377048
# min     1.000000   0.000000    0.000000   0.000000   7.000000   0.000000
# 25%     2.000000   0.000000  132.500000   0.750000  12.000000   3.000000
# 50%     2.500000   1.000000  180.000000   1.750000  14.861842   7.000000
# 75%     3.000000   2.000000  212.500000   3.000000  17.000000  11.000000
# max     6.000000   5.000000  320.000000  14.000000  23.000000  15.000000
#
#            potass    vitamins
# count   76.000000   76.000000
# mean    96.216216   28.289474
# std     66.687384   22.487813
# min     15.000000    0.000000
# 25%     43.750000   25.000000
# 50%     90.000000   25.000000
# 75%    120.000000   25.000000
# max    330.000000  100.000000

# %% [markdown]
# Yes, I think this strategy used to treat the missing values was effective as the missing values in a particular attribute have been replaced with the arithmetic mean of that attribute.

# %% [markdown]
# ### 4) For each of the numeric attributes (proteins upto vitamins), identify and replace all  noisy data with the median of attribute.

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# In the above boxplot,  we can clearly see the outliers in few of the numeric attributes, so we need to remove them.
# In order to find the outliers, we need to find the Lower and upper bounds of the attributes or the z-score of that attributes.

# %%
# let summ be the summary of descriptive statistics of the dataframe df2.

summ = pd.DataFrame(df2.describe().T)

summ["IQR"] = summ["75%"] - summ["25%"]
summ
# Out:
#           count        mean        std   min     25%         50%    75%  \
# protein    76.0    2.526316   1.089020   1.0    2.00    2.500000    3.0
# fat        76.0    1.013158   1.013159   0.0    0.00    1.000000    2.0
# sodium     76.0  160.065789  84.318813   0.0  132.50  180.000000  212.5
# fiber      76.0    2.048684   2.219038   0.0    0.75    1.750000    3.0
# carbo      76.0   14.930575   3.737575   7.0   12.00   14.861842   17.0
# sugars     76.0    7.038608   4.377048   0.0    3.00    7.000000   11.0
# potass     76.0   96.216216  66.687384  15.0   43.75   90.000000  120.0
# vitamins   76.0   28.289474  22.487813   0.0   25.00   25.000000   25.0
#
#             max    IQR
# protein     6.0   1.00
# fat         5.0   2.00
# sodium    320.0  80.00
# fiber      14.0   2.25
# carbo      23.0   5.00
# sugars     15.0   8.00
# potass    330.0  76.25
# vitamins  100.0   0.00

# %%
summ["LowerBound"] = summ["25%"] - summ["IQR"]*1.5
summ["UpperBound"] = summ["75%"] + summ["IQR"]*1.5
summ
# Out:
#           count        mean        std   min     25%         50%    75%  \
# protein    76.0    2.526316   1.089020   1.0    2.00    2.500000    3.0
# fat        76.0    1.013158   1.013159   0.0    0.00    1.000000    2.0
# sodium     76.0  160.065789  84.318813   0.0  132.50  180.000000  212.5
# fiber      76.0    2.048684   2.219038   0.0    0.75    1.750000    3.0
# carbo      76.0   14.930575   3.737575   7.0   12.00   14.861842   17.0
# sugars     76.0    7.038608   4.377048   0.0    3.00    7.000000   11.0
# potass     76.0   96.216216  66.687384  15.0   43.75   90.000000  120.0
# vitamins   76.0   28.289474  22.487813   0.0   25.00   25.000000   25.0
#
#             max    IQR  LowerBound  UpperBound
# protein     6.0   1.00       0.500       4.500
# fat         5.0   2.00      -3.000       5.000
# sodium    320.0  80.00      12.500     332.500
# fiber      14.0   2.25      -2.625       6.375
# carbo      23.0   5.00       4.500      24.500
# sugars     15.0   8.00      -9.000      23.000
# potass    330.0  76.25     -70.625     234.375
# vitamins  100.0   0.00      25.000      25.000

# %%
summ["25%"].protein
# Out:
# 2.0

# %%
col = list(df2.columns)
col
# Out:
# ['protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins']

# %%
for i in col:
    if ([df2[i] < summ["25%"].i == True):
        df2[]
        
        
        
#  || df2[i] > summ["75%"].i
# Out:
#   File "<ipython-input-200-139e7fa504b7>", line 2
#     if ([df2[i] < summ["25%"].i == True):
#                                        ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['
